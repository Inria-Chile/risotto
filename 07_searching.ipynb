# %%
import whoosh

from risotto.artifacts import load_papers_artifact, load_papers_topics_artifacts, load_topics_artifacts

# %%
papers_artifact = load_papers_artifact()
papers_artifact
# Out:
#           pagerank                                       sha  \
# cord_uid
# ug7v899j  0.000006  d1aafb70c066a2068b02786f8929fd9c900897fb
# 02tnwd4m  0.000008  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d
# ejv2xln0  0.000034  06ced00a5fc04215949aa72528f2eeaae1d58927
# 2b73a28n  0.000008  348055649b6b8cf2b9a376498df9bf41f7123605
# 9785vg6d  0.000008  5f48792a5fa08bed9f56016f4981ae2ca6031b32
# ...            ...                                       ...
# 0y5jaf1m  0.000011  60a342d1b18b2059aa722f46cc9f8b9770b6919c
# 6nrfipz8  0.000006  ac51af9995edb441f0ce4fdc384908daa6e83675
# cmaw7jcn  0.000008  fe0e6e93d67b9a908df01529f2fc1b4bbcac0b39
# 7xj27r98  0.000006  a88f5018666185094c4489ecf577251a68940be0
# ms8sb929  0.000011  73ab5445476f26b4dae4e6979a077d3c67edc5f7
#
#                              source_x  \
# cord_uid
# ug7v899j                          PMC
# 02tnwd4m                          PMC
# ejv2xln0                          PMC
# 2b73a28n                          PMC
# ...

# %%
papers_artifact.columns
# Out:
# Index(['pagerank', 'sha', 'source_x', 'title', 'doi', 'pmcid', 'pubmed_id',
#        'license', 'abstract', 'publish_time', 'authors', 'journal', 'mag_id',
#        'who_covidence_id', 'arxiv_id', 'pdf_json_files', 'pmc_json_files',
#        'url', 's2_id'],
#       dtype='object')

# %%
(papers_artifact["title"] + papers_artifact["abstract"]).str.lower().str.contains("bovine")
# Out:
# cord_uid
# ug7v899j    False
# 02tnwd4m    False
# ejv2xln0    False
# 2b73a28n    False
# 9785vg6d    False
#             ...
# 0y5jaf1m     True
# 6nrfipz8    False
# cmaw7jcn    False
# 7xj27r98    False
# ms8sb929    False
# Length: 59627, dtype: object
